# %% [markdown]
# ### Homework 3 (due 20 Sep 2023)

# %%
# File: HWK3.ipynb

# Section: 52740

# Student Name: Vaishnavi Sathiyamoorthy

# Student UT EID: vs25229

# Date Created: 9/17/2023

# Date Last Modified:

# %% [markdown]
# ##### Task 0: Import Libraries and Read Data

# %%
# import libraries
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# read the data file and create a Pandas dataframe
df = pd.read_csv('Life_Expectancy_Data.csv')

# %% [markdown]
# ##### Task 1: Get Simple Statistics of the Dataset

# %%
# get the size of the dataframe
df.shape
# Out:
# (2938, 21)

# %%
# get the first 8 rows of the dataset
df.head(8)
# Out:
#    Year      Status  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0  2015  Developing             65.0            263.0             62     0.01
# 1  2014  Developing             59.9            271.0             64     0.01
# 2  2013  Developing             59.9            268.0             66     0.01
# 3  2012  Developing             59.5            272.0             69     0.01
# 4  2011  Developing             59.2            275.0             71     0.01
# 5  2010  Developing             58.8            279.0             74     0.01
# 6  2009  Developing             58.6            281.0             77     0.01
# 7  2008  Developing             58.1            287.0             80     0.03
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0               71.279624         65.0      1154   19.1  ...    6.0
# 1               73.523582         62.0       492   18.6  ...   58.0
# 2               73.219243         64.0       430   18.1  ...   62.0
# 3               78.184215         67.0      2787   17.6  ...   67.0
# 4                7.097109         68.0      3013   17.2  ...   68.0
# 5               79.679367         66.0      1989   16.7  ...   66.0
# 6               56.762217         63.0      2861   16.2  ...   63.0
# 7               25.873925         64.0      1599   15.7  ...   64.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
# 5               9.20         66.0        0.1  553.328940   2883167.0
# 6               9.42         63.0        0.1  445.893298    284331.0
# 7               8.33         64.0        0.1  373.361116   2729431.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
# 5                   18.4                 18.4
# 6                   18.6                 18.7
# 7                   18.8                 18.9
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
# 7                            0.433        8.7
#
# [8 rows x 21 columns]

# %%
# get the last 6 rows of the dataset
df.tail(6)
# Out:
#       Year      Status  Life expectancy  Adult Mortality  infant deaths  \
# 2932  2005  Developing             44.6            717.0             28
# 2933  2004  Developing             44.3            723.0             27
# 2934  2003  Developing             44.5            715.0             26
# 2935  2002  Developing             44.8             73.0             25
# 2936  2001  Developing             45.3            686.0             25
# 2937  2000  Developing             46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 2932     4.14                8.717409         65.0       420   27.5  ...
# 2933     4.36                0.000000         68.0        31   27.1  ...
# 2934     4.06                0.000000          7.0       998   26.7  ...
# 2935     4.43                0.000000         73.0       304   26.3  ...
# 2936     1.72                0.000000         76.0       529   25.9  ...
# 2937     1.68                0.000000         79.0      1483   25.5  ...
#
#       Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 2932   69.0               6.44         68.0       30.3  444.765750
# 2933   67.0               7.13         65.0       33.6  454.366654
# 2934    7.0               6.52         68.0       36.7  453.351155
# 2935   73.0               6.53         71.0       39.8   57.348340
# 2936   76.0               6.16         75.0       42.1  548.587312
# 2937   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 2932    129432.0                    9.0                  9.0
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 2932                            0.406        9.3
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [6 rows x 21 columns]

# %%
# get the columns of the dataset and their types
df.dtypes
# Out:
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
# get simple statistics of the dataset like - count, max, min, std, mean
df.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %% [markdown]
# ##### TASK 2: Work with Missing Data

# %%
# locate rows that have Null values by running df.isnull()
null_rows = df.isnull().any(axis=1)
df[null_rows]
# Out:
#       Year      Status  Life expectancy  Adult Mortality  infant deaths  \
# 32    2015  Developing             75.6             19.0             21
# 44    2003  Developing             71.7            146.0             20
# 45    2002  Developing             71.6            145.0             20
# 46    2001  Developing             71.4            145.0             20
# 47    2000  Developing             71.3            145.0             21
# ...    ...         ...              ...              ...            ...
# 2918  2003  Developing             46.4             64.0             39
# 2919  2002  Developing             45.5             69.0             41
# 2920  2001  Developing             44.6            611.0             43
# 2921  2000  Developing             43.8            614.0             44
# 2922  2015  Developing             67.0            336.0             22
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 32        NaN                0.000000         95.0        63   59.5  ...
# 44       0.34               25.018523          NaN     15374   47.0  ...
# 45       0.36              148.511984          NaN      5862   46.1  ...
# 46       0.23              147.986071          NaN      2686   45.3  ...
# 47       0.25              154.455944          NaN         0   44.4  ...
# ...       ...                     ...          ...       ...    ...  ...
# 2918     2.33               65.789974          NaN       881   17.6  ...
# 2919     2.44               54.043480          NaN     25036   17.3  ...
# 2920     2.61               46.830275          NaN     16997   17.1  ...
# 2921     2.62               45.616880          NaN     30930   16.8  ...
# 2922      NaN                0.000000         87.0         0   31.8  ...
#
#       Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# 32     95.0                NaN         95.0        0.1  4132.762920
# 44     87.0               3.60         87.0        0.1   294.335560
# 45     86.0               3.73         86.0        0.1  1774.336730
# 46     89.0               3.84         89.0        0.1  1732.857979
# 47     86.0               3.49         86.0        0.1  1757.177970
# ...     ...                ...          ...        ...          ...
# 2918   85.0               8.18         83.0       18.2   429.158343
# 2919   85.0               6.93         84.0       18.4   377.135244
# 2920   86.0               6.56         85.0       18.6   378.273624
# 2921   85.0               7.16         85.0       18.7   341.955625
# 2922   88.0                NaN         87.0        6.2   118.693830
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 32    39871528.0                    6.0                  5.8
# 44     3243514.0                    6.3                  6.1
# 45     3199546.0                    6.3                  6.2
# 46    31592153.0                    6.4                  6.3
# 47     3118366.0                    6.5                  6.4
# ...          ...                    ...                  ...
# 2918  11421984.0                    7.3                  7.2
# 2919    111249.0                    7.4                  7.3
# 2920   1824125.0                    7.4                  7.4
# 2921   1531221.0                    7.5                  7.5
# 2922  15777451.0                    5.6                  5.5
#
#       Income composition of resources  Schooling
# 32                              0.743       14.4
# 44                              0.663       11.5
# 45                              0.653       11.1
# 46                              0.644       10.9
# 47                              0.636       10.7
# ...                               ...        ...
# 2918                            0.443       10.2
# 2919                            0.433       10.0
# 2920                            0.424        9.8
# 2921                            0.418        9.6
# 2922                            0.507       10.3
#
# [1289 rows x 21 columns]

# %%
# find the total number of missing elements per column
for col in df.columns:
  print(col, sum(df[col].isnull()))
# Out:
# Year 0
# Status 0
# Life expectancy 10
# Adult Mortality 10
# infant deaths 0
# Alcohol 194
# percentage expenditure 0
# Hepatitis B 553
# Measles  0
#  BMI  34
# under-five deaths  0
# Polio 19
# Total expenditure 226
# Diphtheria  19
#  HIV/AIDS 0
# GDP 448
# Population 652
#  thinness  1-19 years 34
#  thinness 5-9 years 34
# Income composition of resources 167
# Schooling 163

# %%
# make a heatmap of missing values using seaborn
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
# draconian step: drop any row that contains a Null value
# reset the index after the drop
df.dropna(axis = 0, inplace = True)
df.reset_index(drop = True, inplace = True)

# %%
# run a check that there is no missing values
null_rows = df.isnull().any(axis=1)
df[null_rows]
# Out:
# Empty DataFrame
# Columns: [Year, Status, Life expectancy, Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles ,  BMI , under-five deaths , Polio, Total expenditure, Diphtheria ,  HIV/AIDS, GDP, Population,  thinness  1-19 years,  thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 21 columns]

# %%
# use a heatmap to visually demonstrate that there are no missing values
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# Dropping any row that has a single missing value is extreme. Let us that we were going to study the relationship between 'Life expectancy' and 'GDP' and 'Schooling'. Our expectation is that there will be a higher life expectancy with higher GDP and higher schooling.

# %%
# reread the raw data again
df = pd.read_csv ('Life_Expectancy_Data.csv')

# %%
# drop rows that have missing 'Life expectancy', 'GDP', and 'Schooling'
# these data are essential to our study
df.dropna(subset = ['Life expectancy', 'GDP', 'Schooling'], axis = 0, inplace = True)
df.reset_index(drop = True, inplace = True)
df
# Out:
#       Year      Status  Life expectancy  Adult Mortality  infant deaths  \
# 0     2015  Developing             65.0            263.0             62
# 1     2014  Developing             59.9            271.0             64
# 2     2013  Developing             59.9            268.0             66
# 3     2012  Developing             59.5            272.0             69
# 4     2011  Developing             59.2            275.0             71
# ...    ...         ...              ...              ...            ...
# 2477  2004  Developing             44.3            723.0             27
# 2478  2003  Developing             44.5            715.0             26
# 2479  2002  Developing             44.8             73.0             25
# 2480  2001  Developing             45.3            686.0             25
# 2481  2000  Developing             46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0        0.01               71.279624         65.0      1154   19.1  ...
# 1        0.01               73.523582         62.0       492   18.6  ...
# 2        0.01               73.219243         64.0       430   18.1  ...
# 3        0.01               78.184215         67.0      2787   17.6  ...
# 4        0.01                7.097109         68.0      3013   17.2  ...
# ...       ...                     ...          ...       ...    ...  ...
# 2477     4.36                0.000000         68.0        31   27.1  ...
# 2478     4.06                0.000000          7.0       998   26.7  ...
# 2479     4.43                0.000000         73.0       304   26.3  ...
# 2480     1.72                0.000000         76.0       529   25.9  ...
# 2481     1.68                0.000000         79.0      1483   25.5  ...
#
#       Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0       6.0               8.16         65.0        0.1  584.259210
# 1      58.0               8.18         62.0        0.1  612.696514
# 2      62.0               8.13         64.0        0.1  631.744976
# 3      67.0               8.52         67.0        0.1  669.959000
# 4      68.0               7.87         68.0        0.1   63.537231
# ...     ...                ...          ...        ...         ...
# 2477   67.0               7.13         65.0       33.6  454.366654
# 2478    7.0               6.52         68.0       36.7  453.351155
# 2479   73.0               6.53         71.0       39.8   57.348340
# 2480   76.0               6.16         75.0       42.1  548.587312
# 2481   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2477  12777511.0                    9.4                  9.4
# 2478  12633897.0                    9.8                  9.9
# 2479    125525.0                    1.2                  1.3
# 2480  12366165.0                    1.6                  1.7
# 2481  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2477                            0.407        9.2
# 2478                            0.418        9.5
# 2479                            0.427       10.0
# 2480                            0.427        9.8
# 2481                            0.434        9.8
#
# [2482 rows x 21 columns]

# %%
# check that there are no missing values for the columns 'Life expectancy',
# 'GDP', and 'Schooling'.
null_rows = df.isnull().any(axis=1)
print(df.loc[:, ["Life expectancy", 'GDP', 'Schooling']].isnull().iloc[:, 0].sum())
print(df.loc[:, ["Life expectancy", 'GDP', 'Schooling']].isnull().iloc[:, 1].sum())
print(df.loc[:, ["Life expectancy", 'GDP', 'Schooling']].isnull().iloc[:, 2].sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# An alternative to dropping the missing values would be to replace the missing values with the median for that column since the median is not that sensitive to outliers.

# %%
# reread the raw data again
df = pd.read_csv ('Life_Expectancy_Data.csv')

# %%
# replace the missing values in columns 'Life expectancy', 'GDP', and
# 'Schooling' with the median values for these columns
df['Life expectancy'].replace(np.nan, df.describe().iloc[1, 1], inplace=True)
df['GDP'].replace(np.nan, df.describe().iloc[1, 14], inplace=True)
df['Schooling'].replace(np.nan, df.describe().iloc[1, -1], inplace=True)

# %%
# check that the replacements took place
print(sum(df.loc[:, 'Life expectancy'].isnull()))
print(sum(df.loc[:, 'GDP'].isnull()))
print(sum(df.loc[:, 'Schooling'].isnull()))
# Out:
# 0
# 0
# 0

# %% [markdown]
# ##### Task 3: One-Hot Encoding
# One-Hot Encoding is a process of transforming categorical data into numerical data. Research how this is done in Pandas.

# %%
# reread the raw data again
df = pd.read_csv ('Life_Expectancy_Data.csv')

# %% [markdown]
# The column 'Status' has categorical data. That data classifies countries as either 'Developing' or 'Developed'.

# %%
# check the actual categorical values used
df['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
# research the function get_dummies()
Status_Encoded = pd.get_dummies(df['Status'])
print(Status_Encoded)
# Out:
#       Developed  Developing
# 0             0           1
# 1             0           1
# 2             0           1
# 3             0           1
# 4             0           1
# ...         ...         ...
# 2933          0           1
# 2934          0           1
# 2935          0           1
# 2936          0           1
# 2937          0           1
#
# [2938 rows x 2 columns]

# %%
# instead of 'True' and 'False' have 1 and 0.
# add the two columns 'Developed' and 'Developing' after 'Status'
df= pd.concat([df,Status_Encoded], axis=1)
df
# Out:
#       Year      Status  Life expectancy  Adult Mortality  infant deaths  \
# 0     2015  Developing             65.0            263.0             62
# 1     2014  Developing             59.9            271.0             64
# 2     2013  Developing             59.9            268.0             66
# 3     2012  Developing             59.5            272.0             69
# 4     2011  Developing             59.2            275.0             71
# ...    ...         ...              ...              ...            ...
# 2933  2004  Developing             44.3            723.0             27
# 2934  2003  Developing             44.5            715.0             26
# 2935  2002  Developing             44.8             73.0             25
# 2936  2001  Developing             45.3            686.0             25
# 2937  2000  Developing             46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0        0.01               76.279624         65.0      1154   19.1  ...
# 1        0.01               78.523582         62.0       492   18.6  ...
# 2        0.01               78.219243         64.0       430   18.1  ...
# 3        0.01               83.184215         67.0      2787   17.6  ...
# 4        0.01               12.097109         68.0      3013   17.2  ...
# ...       ...                     ...          ...       ...    ...  ...
# 2933     4.36                5.000000         68.0        31   27.1  ...
# 2934     4.06                5.000000          7.0       998   26.7  ...
# 2935     4.43                5.000000         73.0       304   26.3  ...
# 2936     1.72                5.000000         76.0       529   25.9  ...
# 2937     1.68                5.000000         79.0      1483   25.5  ...
#
#              GDP  Population   thinness  1-19 years   thinness 5-9 years  \
# 0     584.259210  33736494.0                   17.2                 17.3
# 1     612.696514    327582.0                   17.5                 17.5
# 2     631.744976  31731688.0                   17.7                 17.7
# 3     669.959000   3696958.0                   17.9                 18.0
# 4      63.537231   2978599.0                   18.2                 18.2
# ...          ...         ...                    ...                  ...
# 2933  454.366654  12777511.0                    9.4                  9.4
# 2934  453.351155  12633897.0                    9.8                  9.9
# 2935   57.348340    125525.0                    1.2                  1.3
# 2936  548.587312  12366165.0                    1.6                  1.7
# 2937  547.358878  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling     z_gdp     gdp_z  \
# 0                               0.479       10.1 -0.483449 -0.483546
# 1                               0.476       10.0 -0.481456 -0.481553
# 2                               0.470        9.9 -0.480121 -0.480218
# 3                               0.463        9.8 -0.477443 -0.477539
# 4                               0.454        9.5 -0.519939 -0.520044
# ...                               ...        ...       ...       ...
# 2933                            0.407        9.2 -0.492551 -0.492650
# 2934                            0.418        9.5 -0.492623 -0.492722
# 2935                            0.427       10.0 -0.520373 -0.520477
# 2936                            0.427        9.8 -0.485949 -0.486046
# 2937                            0.434        9.8 -0.486035 -0.486132
#
#       Developed  Developing
# 0             0           1
# 1             0           1
# 2             0           1
# 3             0           1
# 4             0           1
# ...         ...         ...
# 2933          0           1
# 2934          0           1
# 2935          0           1
# 2936          0           1
# 2937          0           1
#
# [2938 rows x 25 columns]

# %%
# check that the columns were added correctly
df.iloc[:, -2:]
# Out:
#       Developed  Developing
# 0             0           1
# 1             0           1
# 2             0           1
# 3             0           1
# 4             0           1
# ...         ...         ...
# 2933          0           1
# 2934          0           1
# 2935          0           1
# 2936          0           1
# 2937          0           1
#
# [2938 rows x 2 columns]

# %%
# print the number of 'Developed' and 'Developing' countries
print("Developed", Status_Encoded['Developed'].sum())
print("Developing", Status_Encoded['Developing'].sum())
# Out:
# Developed 512
# Developing 2426

# %%
# print the mean 'Life expectancy' of 'Developed' countries
df[df['Status'] == "Developed"].describe().loc["mean", 'Life expectancy']
# Out:
# 79.1978515625

# %%
# print the mean 'Life expectancy' of 'Developing' countries
df[df['Status'] == "Developing"].describe().loc["mean", 'Life expectancy']
# Out:
# 67.11146523178809

# %% [markdown]
# ##### Task 4: Normalize Data

# %% [markdown]
# Normalization is peformed to have data values in the range from 0 to 1.
#
# x_normal = (x_raw - x_min) / (x_max - x_min)
#
# Use MinMaxScaler in scikit-learn to perform the transformation

# %%
# reread the raw data again
df = pd.read_csv ('Life_Expectancy_Data.csv')

# %%
# show the values
df['Life expectancy'].values
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
# normalization makes the transformed values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['Life expectancy'] = scaler.fit_transform(df['Life expectancy'].values.reshape(-1,1))

# %%
# show the values
df['Life expectancy']
# Out:
# 0       0.544592
# 1       0.447818
# 2       0.447818
# 3       0.440228
# 4       0.434535
#           ...
# 2933    0.151803
# 2934    0.155598
# 2935    0.161290
# 2936    0.170778
# 2937    0.184061
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
# redo the statistics
df['Life expectancy'].describe()
# Out:
# count    2928.000000
# mean        0.624762
# std         0.180719
# min         0.000000
# 25%         0.508539
# 50%         0.679317
# 75%         0.747628
# max         1.000000
# Name: Life expectancy, dtype: float64

# %%
# reread the raw data again
df = pd.read_csv ('Life_Expectancy_Data.csv')

# %%
# normalize the data for 'Life expectancy', 'GDP', and 'Schooling'
# instead of over-writing the raw values create three columns:
# 'life_expectancy_normal', 'gdp_normal', and 'schooling_normal' and
# fill them with normalized data
df['Life_expectancy_normal'] = scaler.fit_transform(df['Life expectancy'].values.reshape(-1,1))
df['gdp_normal'] = scaler.fit_transform(df['GDP'].values.reshape(-1,1))
df['Schooling_normal'] = scaler.fit_transform(df['Schooling'].values.reshape(-1,1))

# %%
# check that these three columns were created with normalized data
df.iloc[:, -3:]
# Out:
#       Life_expectancy_normal  gdp_normal  Schooling_normal
# 0                   0.544592    0.004889          0.487923
# 1                   0.447818    0.005127          0.483092
# 2                   0.447818    0.005287          0.478261
# 3                   0.440228    0.005608          0.473430
# 4                   0.434535    0.000519          0.458937
# ...                      ...         ...               ...
# 2933                0.151803    0.003799          0.444444
# 2934                0.155598    0.003790          0.458937
# 2935                0.161290    0.000467          0.483092
# 2936                0.170778    0.004589          0.473430
# 2937                0.184061    0.004579          0.473430
#
# [2938 rows x 3 columns]

# %% [markdown]
# ##### Task 5: Perform Standardization

# %% [markdown]
# Standardization is performed to transform data to have a mean of zero
# and standard deviation of 1.
#
# The standardized value is also called the z-score.
#
# x_z = (x_raw - x_mean) / x_std
#
# Use StandardScaler in scikit-learn to perform the standardization.

# %%
# reread the raw data again
df = pd.read_csv ('Life_Expectancy_Data.csv')

# %%
# get the life expectancy values
df['Life expectancy'].values
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
# Standardization transforms values to have a mean of 0 and standard
# deviation of 1
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['Life expectancy'] = scaler.fit_transform(df['Life expectancy'].values.reshape(-1,1))

# %%
# check the standardized values
df['Life expectancy']
# Out:
# 0      -0.443691
# 1      -0.979279
# 2      -0.979279
# 3      -1.021286
# 4      -1.052791
#           ...
# 2933   -2.617549
# 2934   -2.596545
# 2935   -2.565040
# 2936   -2.512532
# 2937   -2.439020
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
# run simple statistics on that column
df['Life expectancy'].describe()
# Out:
# count    2.928000e+03
# mean    -6.891876e-16
# std      1.000171e+00
# min     -3.457687e+00
# 25%     -6.432238e-01
# 50%      3.019319e-01
# 75%      6.799942e-01
# max      2.076724e+00
# Name: Life expectancy, dtype: float64

# %%
# reread the raw data again
df = pd.read_csv ('Life_Expectancy_Data.csv')

# %%
# standardize the data for 'Life expectancy', 'GDP', and 'Schooling'
# instead of over-writing the raw values create three columns:
# 'life_expectancy_z', 'gdp_z', and 'schooling_z' and
# fill them with standardized data
df['Life_expectancy_z'] = scaler.fit_transform(df['Life expectancy'].values.reshape(-1,1))
df['gdp_z'] = scaler.fit_transform(df['GDP'].values.reshape(-1,1))
df['Schooling_z'] = scaler.fit_transform(df['Schooling'].values.reshape(-1,1))

# %%
# check that these three columns were created with standardized data
df.iloc[:, -3:]
# Out:
#       Life_expectancy_z     gdp_z  Schooling_z
# 0             -0.443691 -0.483546    -0.563614
# 1             -0.979279 -0.481553    -0.593391
# 2             -0.979279 -0.480218    -0.623168
# 3             -1.021286 -0.477539    -0.652944
# 4             -1.052791 -0.520044    -0.742275
# ...                 ...       ...          ...
# 2933          -2.617549 -0.492650    -0.831606
# 2934          -2.596545 -0.492722    -0.742275
# 2935          -2.565040 -0.520477    -0.593391
# 2936          -2.512532 -0.486046    -0.652944
# 2937          -2.439020 -0.486132    -0.652944
#
# [2938 rows x 3 columns]

# %% [markdown]
# ##### Task 6: Applying Custom Function to Transform Data

# %%
# reread the raw data again
df = pd.read_csv ('Life_Expectancy_Data.csv')

# %%
# asuume that percentage expenditure has increased by 5%
# define a function that increases all elements by a fixed value of 5% (for simplicity sake)
def percentage_expenditure_update(balance):
    return balance + 5

# %%
# apply that function to the DataFrame
df['percentage expenditure'] = df['percentage expenditure'].apply(percentage_expenditure_update)

# %%
# check that the values in 'percentage expenditure' did change
df['percentage expenditure']
# Out:
# 0       76.279624
# 1       78.523582
# 2       78.219243
# 3       83.184215
# 4       12.097109
#           ...
# 2933     5.000000
# 2934     5.000000
# 2935     5.000000
# 2936     5.000000
# 2937     5.000000
# Name: percentage expenditure, Length: 2938, dtype: float64

# %%
# create your own function to perform standardization
# x_z = (x_raw - x_mean) / x_std
def standardize (mean, std, value):
  return (value - mean) / std

# %%
# apply the function standardize() to the GDP values.
# store the results in a new column called z_gdp
df["z_gdp"] = standardize(df.describe().loc["mean", "GDP"], df.describe().loc["std", "GDP"], df["GDP"])

# %%
# compare your standardized values with those obtained from scikit-learn
df['gdp_z'] = scaler.fit_transform(df['GDP'].values.reshape(-1,1))
print(df["z_gdp"])
print(df['gdp_z'])
# Out:
# 0      -0.483449
# 1      -0.481456
# 2      -0.480121
# 3      -0.477443
# 4      -0.519939
#           ...
# 2933   -0.492551
# 2934   -0.492623
# 2935   -0.520373
# 2936   -0.485949
# 2937   -0.486035
# Name: z_gdp, Length: 2938, dtype: float64
# 0      -0.483546
# 1      -0.481553
# 2      -0.480218
# 3      -0.477539
# 4      -0.520044
#           ...
# 2933   -0.492650
# 2934   -0.492722
# 2935   -0.520477
# 2936   -0.486046
# 2937   -0.486132
# Name: gdp_z, Length: 2938, dtype: float64
